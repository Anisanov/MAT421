# %% [markdown]
# # ODE Approximation

# %% [markdown]
# The following is an approximation of $\frac{d f(x)}{dx} = sin(x)$ with initial condition $f_{0}=0$. The exact solution is $f(x)=1-cos(x)$

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt

# Defining ODE approximation function
def ODEapprox(h):
    # Setting function parameters
    x = np.arange(0, 1 + h, h) # Inputs
    f = lambda x, s: np.sin(x) # Outputs
    f0 = 0 # Initial Condition

    # Explicit Euler Method
    s = np.zeros(len(x))
    s[0] = f0
    for i in range(0, len(x) - 1):
        s[i + 1] = s[i] + h * f(x[i], s[i])

    # Displaying Output
    plt.style.use("seaborn")
    plt.figure(figsize = (12, 8))
    plt.plot(x, s, "r--", label="Approximate")
    plt.plot(x, 1-np.cos(x), "b", label="Exact")
    plt.title("ODE Approximate and Exact Solution")
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.legend(loc="upper left")
    plt.show()

# %%
# Executing function for step size h = 0.25
ODEapprox(0.25)

# %%
# Executing function for step size h = 0.1
ODEapprox(0.1)

# %%
# Executing function for step size h = 0.01
ODEapprox(0.01)
